# %%
# data organization libraries
import numpy as np
import pandas as pd

# data visualization libraries
import plotly.express as px
import matplotlib.pyplot as plt

# modeling libraries
import sklearn as sk

# %%
# download data and extract some info

fire_df = pd.read_csv('forestfires.csv')

fire_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       517 non-null    int64
#  1   Y       517 non-null    int64
#  2   month   517 non-null    object
#  3   day     517 non-null    object
#  4   FFMC    517 non-null    float64
#  5   DMC     517 non-null    float64
#  6   DC      517 non-null    float64
#  7   ISI     517 non-null    float64
#  8   temp    517 non-null    float64
#  9   RH      517 non-null    int64
#  10  wind    517 non-null    float64
#  11  rain    517 non-null    float64
#  12  area    517 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB

# %%
len(fire_df)
# Out:
# 517

# %%
fire_df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
months = fire_df['month'].value_counts()

months
# Out:
# aug    184
# sep    172
# mar     54
# jul     32
# feb     20
# jun     17
# oct     15
# apr      9
# dec      9
# may      2
# jan      2
# nov      1
# Name: month, dtype: int64

# %%
#remove all zero burn data points

months_to_remove = ['nov', 'jan', 'may']

month_drop = fire_df.drop(fire_df[fire_df['month'].isin(months_to_remove)].index, axis=0)

clean_fire = month_drop.drop(month_drop[month_drop['']])



clean_fire.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-63b3c6689e79> in <module>
#       5 month_drop = fire_df.drop(fire_df[fire_df['month'].isin(months_to_remove)].index, axis=0)
#       6
# ----> 7 clean_fire
#       8
#       9
#
# NameError: name 'clean_fire' is not defined

# %%
len(clean_fire)

# %%
s_f = fire_df[['X', 'Y', 'month', 'day', 'wind', 'rain', 'area']]

s_f.head()
# Out:
#    X  Y month  day  wind  rain  area
# 0  7  5   mar  fri   6.7   0.0   0.0
# 1  7  4   oct  tue   0.9   0.0   0.0
# 2  7  4   oct  sat   1.3   0.0   0.0
# 3  8  6   mar  fri   4.0   0.2   0.0
# 4  8  6   mar  sun   1.8   0.0   0.0

# %%
len(s_f)
# Out:
# 517

# %%
s_f.describe()
# Out:
#                 X           Y        wind        rain         area
# count  517.000000  517.000000  517.000000  517.000000   517.000000
# mean     4.669246    4.299807    4.017602    0.021663    12.847292
# std      2.313778    1.229900    1.791653    0.295959    63.655818
# min      1.000000    2.000000    0.400000    0.000000     0.000000
# 25%      3.000000    4.000000    2.700000    0.000000     0.000000
# 50%      4.000000    4.000000    4.000000    0.000000     0.520000
# 75%      7.000000    5.000000    4.900000    0.000000     6.570000
# max      9.000000    9.000000    9.400000    6.400000  1090.840000

# %%
import plotly.express as px


fig = px.scatter(s_f, x="rain", y="wind", size="area", color="month",
           hover_name="day", size_max=60)
fig.show()
# Out:
# <div>                            <div id="68e7a870-c8c1-4984-a01d-7ad2a5344b24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68e7a870-c8c1-4984-a01d-7ad2a5344b24")) {                    Plotly.newPlot(                        "68e7a870-c8c1-4984-a01d-7ad2a5344b24",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>month=mar<br>rain=%{x}<br>wind=%{y}<br>area=%{marker.size}<extra></extra>", "hovertext": ["fri", "fri", "sun", "sat", "wed", "tue", "mon", "mon", "sun", "sun", "fri", "fri", "fri", "mon", "sat", "fri", "sat", "fri", "thu", "fri", "fri", "tue", "tue", "sat", "sat", "mon", "mon", "mon", "sun", "tue", "mon", "mon", "sat", "thu", "fri", "sun", "sat", "sun", "fri", "sun", "sat", "mon", "sat", "sat", "mon", "mon", "thu", "t
# ...
